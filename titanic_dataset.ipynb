# %%
import os #provides functions for interacting with the operating system
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/content/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(['PassengerId'], axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
df.describe().T
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # -the dimensions of this data is 891 rows in 12 columns
# # -this data set has 12 features
# # -it has both qualtive and quntative data
# # -it does include nulls
# # -it does not have any duplicates
# # - yes it does have outliers

# %%
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

# %%
for col in df.columns[2:10]:
    print(col, np.unique(df[col]))
    print(col, df[col].value_counts())
# Out:
# Pclass [1 2 3]
# Pclass 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# Name ['Abbing, Mr. Anthony' 'Abbott, Mr. Rossmore Edward'
#  'Abbott, Mrs. Stanton (Rosa Hunt)' 'Abelson, Mr. Samuel'
#  'Abelson, Mrs. Samuel (Hannah Wizosky)' 'Adahl, Mr. Mauritz Nils Martin'
#  'Adams, Mr. John' 'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)'
#  'Aks, Mrs. Sam (Leah Rosen)' 'Albimona, Mr. Nassef Cassem'
#  'Alexander, Mr. William' 'Alhomaki, Mr. Ilmari Rudolf' 'Ali, Mr. Ahmed'
#  'Ali, Mr. William' 'Allen, Miss. Elisabeth Walton'
#  'Allen, Mr. William Henry' 'Allison, Master. Hudson Trevor'
#  'Allison, Miss. Helen Loraine'
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)'
#  'Allum, Mr. Owen George'
#  'Andersen-Jensen, Miss. Carla Christine Nielsine' 'Anderson, Mr. Harry'
#  'Andersson, Master. Sigvard Harald Elias'
#  'Andersson, Miss. Ebba Iris Alfrida' 'Andersson, Miss. Ellis Anna Maria'
#  'Andersson, Miss. Erna Alexandra' 'Andersson, Miss. Ingeborg Constanzia'
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns


sns.catplot(x='Pclass', data=df, hue='Survived', col='Sex',palette='ch:.25', kind='count')

# %% [markdown]
# # we have a very clear insight that class number 3 has the highest death count becuase there third class and on the titanic the lower your class the lower you are physically on the ship
# # we can also notice that hieghst death in pclasee 3 is among males
# # we can also conclude that more women survived more then men espically in first and second class we have way more female survivors

# %%
ages_survived = df[df['Survived'] == 1]['Age']


plt.hist(ages_survived)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages for Survived Individuals')
plt.show()

# %% [markdown]
# most of the survivors were middleaged between 18 and 30

# %%
sns.catplot(x='SibSp', data=df, hue='Survived',palette='ch:.25', kind='count')

# %% [markdown]
# people who were alone most likley survived the more sblings they had with them the less of chance they have to survive and people with 5 siblings and up didnot survive at all

# %%
sns.catplot(x='SibSp', data=df, hue='Pclass',palette='ch:.25', kind='count')

# %% [markdown]
# most of the third class didnot have sibs because most of them were workers

# %%
sns.violinplot(x='Embarked', y="Pclass", data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='Pclass'>

# %% [markdown]
# ## we can conclude that almost all of the people who embarked from Q are on third class meaning its probably a pour town while first class is mostly populated by C meaning C is an upper-middle class area

# %%
sns.catplot(x='Embarked', data=df, hue='Survived',palette='ch:.25', kind='count')

# %% [markdown]
# we can also notice here that people from area C have a higher chance of survival
# while areas S and Q have a worst chance of survival

# %%
sns.catplot(x='Embarked', data=df, hue='SibSp',palette='ch:.25', kind='count')

# %% [markdown]
# we can notice here that most of the people who embarked from all towns were alone but area S has is where most the people with up to 8 Sibs embarked from

# %%
sns.catplot(x='Survived', data=df, hue='Survived',palette='ch:.25', kind='count')

# %% [markdown]
# most of the people on board didnot make it but on onther note a good amount did survive

# %%
grouped_data = df.groupby('Embarked')['Fare'].mean()

plt.scatter(grouped_data.index, grouped_data.values)
plt.xlabel('Embarked')
plt.ylabel('Mean Fare')
plt.title('Mean Fare by Embarked')
plt.show()

# %% [markdown]
# ## the ticket fair was highest if embarked from C and second highest if Embarked from S and lowest at Q
# we can confirm from this that C was an upper class area and S was middle and Q was lower class or mostly workers

# %%
sns.countplot(x='Embarked', data=df, hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
ages_survived = df[df['Pclass'] == 3]['Age']


plt.hist(ages_survived)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages for Survived Individuals')
plt.show()

# %% [markdown]
# we can also note that most of the third class were aged from around 16 to 27
# confirming that third class were mostly young teens and adults looking for work

# %%
ages_survived = df[df['Pclass'] == 1]['Age']


plt.hist(ages_survived)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages for Survived Individuals')
plt.show()

# %% [markdown]
# we can also find that most of first class passengers were aged from 30 to 40 confirming they were wealthy on-board most-likely for a cruise

# %%
ages_survived = df[df['Pclass'] == 2]['Age']


plt.hist(ages_survived)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Ages for Survived Individuals')
plt.show()

# %% [markdown]
# we can also find the second class was more of a middle class for the common

# %% [markdown]
# # conclusion
# # we have a very clear insight that class number 3 has the highest death count becuase there third class and on the titanic the lower your class the lower you are physically on the ship
# # we can also notice that hieghst death in pclasee 3 is among males
# # we can also conclude that more women survived more then men espically in first and second class we have way more female survivors
# # most of the survivors were middleaged between 18 and 30
# # people who were alone most likley survived the more sblings they had with them the less of chance they have to survive and people with 5 siblings and up didnot survive at all
# # most of the third class didnot have sibs because most of them were workers
# # we can conclude that almost all of the people who embarked from Q are on third class meaning its probably a pour town while first class is mostly populated by C meaning C is an upper-middle class area
# # we can also notice here that people from area C have a higher chance of survival while areas S and Q have a worst chance of survival
# # we can also notice here that people from area C have a higher chance of survival
#
# # we can notice here that most of the people who embarked from all towns were alone but area S has is where most the people with up to 8 Sibs embarked from
# #
# ## the ticket fair was highest if embarked from C and second highest if Embarked from S and lowest at Q
# # we can confirm from this that C was an upper class area and S was middle and Q was lower class or mostly workers
# # we can also note that most of the third class were aged from around 16 to 27
# # confirming that third class were mostly young teens and adults looking for work
# # we can also find that most of first class passengers were aged from 30 to 40 confirming they were wealthy on-board most-likely for a cruise
# # we can also find the second class was more of a middle class for the common
